# %%
import torch
import torchvision
import torch.nn.functional as F
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils.tools import dotdict
from driver.driver import ABC_Driver
from torch_geometric_temporal import METRLADatasetLoader
from other_model.other_model import make_default_model
import atd2022
torch.cuda.is_available()
torch.cuda.set_device(2)

# %%
cifar10_args = dotdict()

cifar10_args.name = 'cifar10'
cifar10_args.train_batch_size = 128
cifar10_args.predict_batch_size = 128
cifar10_args.device = ['cuda:2','cuda:3']

cifar10_args.train_epochs = 250
cifar10_args.lr = 0.01
cifar10_args.criterion = 'CE'
cifar10_args.optimizer = 'AdamW'
cifar10_args.scheduler = 'OneCycle'
cifar10_args.attack = {'fgsm':(0.031,), 'pgd':(0.031,1,20)}

activation = 'relu'
input_channel = 3
knpp = [48,96,144,240,336,432,528]

cifar10_args.layers=[
    ('cnn2d', ((input_channel, knpp[0], (3,3), 1, 1, 1, 1), 1, None, None, activation, False)),
    ('atrc2d', ((knpp[0], knpp[1], (3,3), 1, 1, 1, knpp[0]), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[1], knpp[2], (3,3), 1, 1, 1, knpp[0]), 1, 'first', (2,2), activation, True)),
    ('atrc2d', ((knpp[2], knpp[3], (3,3), 1, 1, 1, knpp[0]), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[3], knpp[4], (3,3), 1, 1, 1, knpp[0]), 1, 'first', (2,2), activation, True)),
    ('atrc2d', ((knpp[4], knpp[5], (3,3), 1, 1, 1, knpp[0]), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[5], knpp[6], (3,3), 1, 1, 1, knpp[0]), 1, 'first', (2,2), activation, True)),
#     ('cnn2d', ((knpp[-1], knpp[-1], (3,3), 1, 0, 1, knpp[0]), 1, None, None, activation, False)),
#     ('cnn2d', ((knpp[-1], knpp[-1], (2,2), 1, 0, 1, knpp[0]), 1, None, None, False, False)),
    ('adptavgpool', (1,1)),
    ('linear', (knpp[-1], 10, (1,2,3)))
]

# %%
cifar100_args = dotdict()

cifar100_args.name = 'cifar100'
cifar100_args.train_batch_size = 100
cifar100_args.predict_batch_size = 100
cifar100_args.device = ['cuda:2','cuda:3']

cifar100_args.train_epochs = 250
cifar100_args.lr = 0.2
cifar100_args.criterion = 'CE'
cifar100_args.optimizer = 'SGD'
cifar100_args.scheduler = 'multistep'
cifar100_args.attack = {'fgsm':(0.005,), 'pgd':(0.005,0.1,20)}

activation = 'relu'
input_channel = 3
knpp = [40, 80, 120, 160, 200, 240, 280, 320, 360, 400]
# knpp = [48,96,144,240,336,432,528]
groups=40

cifar100_args.layers=[
    ('cnn2d', ((input_channel, knpp[0], (3,3), 1, 1, 1, 1), 1, None, None, activation, False)),
    ('atrc2d', ((knpp[0], knpp[1], (3,3), 1, 1, 1, groups), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[1], knpp[2], (3,3), 1, 1, 1, groups), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[2], knpp[3], (3,3), 1, 1, 1, groups), 1, 'first', (2,2), activation, True)),
    ('atrc2d', ((knpp[3], knpp[4], (3,3), 1, 1, 1, groups), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[4], knpp[5], (3,3), 1, 1, 1, groups), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[5], knpp[6], (3,3), 1, 1, 1, groups), 1, 'first', (2,2), activation, True)),
    ('atrc2d', ((knpp[6], knpp[7], (3,3), 1, 1, 1, groups), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[7], knpp[8], (3,3), 1, 1, 1, groups), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[8], knpp[9], (3,3), 1, 1, 1, groups), 1, 'first', (2,2), activation, True)),
#     ('cnn2d', ((knpp[-1], knpp[-1], (3,3), 1, 0, 1, knpp[0]), 1, None, None, activation, False)),
#     ('cnn2d', ((knpp[-1], knpp[-1], (2,2), 1, 0, 1, knpp[0]), 1, None, None, False, False)),
    ('adptavgpool', (1,1)), 
    ('linear', (knpp[-1], 100, (1,2,3)))
]

# %%
driver = ABC_Driver(cifar100_args, None, record_path=None, if_hash=False)
driver.train()
# Out:
# Use: ['cuda:2', 'cuda:3']
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# add record: 03/25/2023 20:00
# epoch: 0, train_loss: 4.3045, test_metric: 0.1112, time: 670.1726574897766
# epoch: 1, train_loss: 3.9027, test_metric: 0.1811, time: 667.0814135074615
# epoch: 2, train_loss: 3.4672, test_metric: 0.2806, time: 666.9277930259705
# epoch: 3, train_loss: 3.0334, test_metric: 0.3591, time: 667.0463027954102
# epoch: 4, train_loss: 2.7571, test_metric: 0.4102, time: 666.8434376716614
# epoch: 5, train_loss: 2.5253, test_metric: 0.4478, time: 667.1520984172821
# epoch: 6, train_loss: 2.3595, test_metric: 0.482, time: 666.8790338039398
# epoch: 7, train_loss: 2.2335, test_metric: 0.4911, time: 666.9742844104767
# epoch: 8, train_loss: 2.1404, test_metric: 0.5055, time: 667.0379712581635
# epoch: 9, train_loss: 2.0652, test_metric: 0.5295, time: 667.0900840759277
# epoch: 10, train_loss: 1.9928, test_metric: 0.5378, time: 666.827228307724
# epoch: 11, train_loss: 1.9347, test_metric: 0.5472, time: 666.7661683559418
# epoch: 12, train_loss: 1.8843, test_metric: 0.5574, time: 667.1621644496918
# epoch: 13, train_loss: 1.8431, test_metric: 0.5588, time: 667.0228998661041
# epoch: 14, train_loss: 1.8029, test_metric: 0.5671, time: 667.1469130516052
# epoch: 15, train_loss: 1.774, test_metric: 0.5939, time: 666.9998545646667
# epoch: 16, train_loss: 1.7447, test_metric: 0.6009, time: 667.0464746952057
# epoch: 17, train_loss: 1.7151, test_metric: 0.5851, time: 648.7622003555298
# epoch: 18, train_loss: 1.6873, test_metric: 0.6019, time: 665.9960796833038
# epoch: 19, train_loss: 1.6678, test_metric: 0.5916, time: 665.8624222278595
# epoch: 20, train_loss: 1.6522, test_metric: 0.5999, time: 666.029176235199
# epoch: 21, train_loss: 1.6363, test_metric: 0.6091, time: 665.9413075447083
# epoch: 22, train_loss: 1.6159, test_metric: 0.6083, time: 665.9610240459442
# epoch: 23, train_loss: 1.6041, test_metric: 0.6019, time: 665.961660861969
# epoch: 24, train_loss: 1.5914, test_metric: 0.6124, time: 665.887617111206
# epoch: 25, train_loss: 1.5674, test_metric: 0.6247, time: 665.9095675945282
# epoch: 26, train_loss: 1.5577, test_metric: 0.6278, time: 667.0021796226501
# epoch: 27, train_loss: 1.5463, test_metric: 0.6296, time: 668.531254529953
# epoch: 28, train_loss: 1.535, test_metric: 0.6375, time: 668.3151390552521
# epoch: 29, train_loss: 1.5245, test_metric: 0.6262, time: 668.777724981308
# epoch: 30, train_loss: 1.2669, test_metric: 0.6849, time: 668.5515050888062
# epoch: 31, train_loss: 1.1969, test_metric: 0.6898, time: 668.6439867019653
# epoch: 32, train_loss: 1.1742, test_metric: 0.6848, time: 668.4827907085419
# epoch: 33, train_loss: 1.1511, test_metric: 0.6837, time: 668.5166664123535
# epoch: 34, train_loss: 1.1396, test_metric: 0.6965, time: 668.590651512146
# epoch: 35, train_loss: 1.1221, test_metric: 0.6817, time: 668.5915901660919
# epoch: 36, train_loss: 1.1165, test_metric: 0.68, time: 668.6543159484863
# epoch: 37, train_loss: 1.1119, test_metric: 0.6863, time: 668.5890007019043
# epoch: 38, train_loss: 1.1007, test_metric: 0.6819, time: 668.9699041843414
# epoch: 39, train_loss: 1.1006, test_metric: 0.6948, time: 669.1789617538452
# epoch: 40, train_loss: 1.1006, test_metric: 0.6914, time: 668.7846076488495
# epoch: 41, train_loss: 1.0952, test_metric: 0.6909, time: 668.9987924098969
# epoch: 42, train_loss: 1.0962, test_metric: 0.6982, time: 668.8658418655396
# epoch: 43, train_loss: 1.0889, test_metric: 0.6864, time: 668.8087818622589
# epoch: 44, train_loss: 1.093, test_metric: 0.6888, time: 668.6314752101898
# epoch: 45, train_loss: 1.0891, test_metric: 0.6871, time: 668.4790849685669
# epoch: 46, train_loss: 1.0885, test_metric: 0.6936, time: 668.4991421699524
# epoch: 47, train_loss: 1.084, test_metric: 0.6889, time: 668.5528028011322
# epoch: 48, train_loss: 1.0833, test_metric: 0.6858, time: 668.8774197101593
# epoch: 49, train_loss: 1.0756, test_metric: 0.6847, time: 668.2533142566681
# epoch: 50, train_loss: 1.0854, test_metric: 0.6976, time: 667.425103187561
# epoch: 51, train_loss: 1.0829, test_metric: 0.6896, time: 667.7623529434204
# epoch: 52, train_loss: 1.0839, test_metric: 0.6832, time: 667.6143050193787
# epoch: 53, train_loss: 1.0757, test_metric: 0.6775, time: 668.123542547226
# epoch: 54, train_loss: 1.0815, test_metric: 0.6892, time: 668.937052488327
# epoch: 55, train_loss: 1.0737, test_metric: 0.6826, time: 668.9997088909149
# epoch: 56, train_loss: 1.0738, test_metric: 0.6818, time: 668.8155176639557
# epoch: 57, train_loss: 1.063, test_metric: 0.6773, time: 668.8141872882843
# epoch: 58, train_loss: 1.0651, test_metric: 0.6834, time: 667.7844431400299
# epoch: 59, train_loss: 1.066, test_metric: 0.6941, time: 668.0994899272919
# epoch: 60, train_loss: 0.87, test_metric: 0.7269, time: 668.1370453834534
# epoch: 61, train_loss: 0.8114, test_metric: 0.7253, time: 668.0793793201447
# epoch: 62, train_loss: 0.7846, test_metric: 0.7305, time: 667.9894049167633
# epoch: 63, train_loss: 0.7727, test_metric: 0.7187, time: 668.8151133060455
# epoch: 64, train_loss: 0.7549, test_metric: 0.7244, time: 668.8758869171143
# epoch: 65, train_loss: 0.7525, test_metric: 0.733, time: 669.0169720649719
# epoch: 66, train_loss: 0.7435, test_metric: 0.7234, time: 668.9185650348663
# epoch: 67, train_loss: 0.7393, test_metric: 0.722, time: 668.9359073638916
# epoch: 68, train_loss: 0.7254, test_metric: 0.726, time: 668.993834733963
# epoch: 69, train_loss: 0.727, test_metric: 0.7254, time: 668.9918329715729
# epoch: 70, train_loss: 0.7289, test_metric: 0.7266, time: 668.160768032074
# epoch: 71, train_loss: 0.7284, test_metric: 0.7198, time: 668.3361246585846
# epoch: 72, train_loss: 0.7183, test_metric: 0.7315, time: 669.0358514785767
# epoch: 73, train_loss: 0.7221, test_metric: 0.7324, time: 669.048709154129
# epoch: 74, train_loss: 0.7239, test_metric: 0.7216, time: 668.2937111854553
# epoch: 75, train_loss: 0.7178, test_metric: 0.7251, time: 668.8859205245972
# epoch: 76, train_loss: 0.7182, test_metric: 0.7204, time: 668.3434128761292
# epoch: 77, train_loss: 0.7189, test_metric: 0.7215, time: 668.583012342453
# epoch: 78, train_loss: 0.7123, test_metric: 0.7196, time: 668.7096514701843
# epoch: 79, train_loss: 0.7222, test_metric: 0.7182, time: 668.6323630809784
# epoch: 80, train_loss: 0.7138, test_metric: 0.7212, time: 668.8337140083313
# epoch: 81, train_loss: 0.716, test_metric: 0.7213, time: 667.8579614162445
# epoch: 82, train_loss: 0.7185, test_metric: 0.7188, time: 667.5187003612518
# epoch: 83, train_loss: 0.7195, test_metric: 0.7197, time: 667.5555837154388
# epoch: 84, train_loss: 0.7184, test_metric: 0.7193, time: 667.6176977157593
# epoch: 85, train_loss: 0.7171, test_metric: 0.7156, time: 667.7071757316589
# epoch: 86, train_loss: 0.7161, test_metric: 0.7133, time: 667.5811975002289
# epoch: 87, train_loss: 0.7086, test_metric: 0.7191, time: 667.4694857597351
# epoch: 88, train_loss: 0.7132, test_metric: 0.7208, time: 667.7386872768402
# epoch: 89, train_loss: 0.7185, test_metric: 0.7194, time: 667.6362454891205
# epoch: 90, train_loss: 0.5872, test_metric: 0.7442, time: 668.3140652179718
# epoch: 91, train_loss: 0.5495, test_metric: 0.7387, time: 668.9662530422211
# epoch: 92, train_loss: 0.5274, test_metric: 0.737, time: 669.0287744998932
# epoch: 93, train_loss: 0.5245, test_metric: 0.7391, time: 668.9587264060974
# epoch: 94, train_loss: 0.5136, test_metric: 0.7415, time: 669.082760810852
# epoch: 95, train_loss: 0.509, test_metric: 0.7403, time: 668.7050573825836
# epoch: 96, train_loss: 0.4987, test_metric: 0.7372, time: 668.3079645633698
# epoch: 97, train_loss: 0.492, test_metric: 0.7454, time: 668.5188889503479
# epoch: 98, train_loss: 0.4971, test_metric: 0.739, time: 669.1527798175812
# epoch: 99, train_loss: 0.494, test_metric: 0.7384, time: 668.8103337287903
# epoch: 101, train_loss: 0.4883, test_metric: 0.739, time: 669.0555934906006
# epoch: 102, train_loss: 0.4869, test_metric: 0.7425, time: 668.8406262397766
# epoch: 103, train_loss: 0.485, test_metric: 0.7374, time: 668.7297086715698
# epoch: 104, train_loss: 0.4853, test_metric: 0.7453, time: 667.7926533222198
# epoch: 105, train_loss: 0.4755, test_metric: 0.7374, time: 668.5224409103394
# epoch: 106, train_loss: 0.4725, test_metric: 0.7417, time: 669.0975210666656

# %%
# torch.save(driver.model.state_dict(), "save/CIFAR100_ABC_2023_03_16.pt")
# driver.model.load_state_dict(torch.load("save/CIFAR100_ABC_2023_03_13.pt"))
