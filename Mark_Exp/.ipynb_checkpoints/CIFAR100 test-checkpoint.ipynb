# %%
import torch
import torchvision
import torch.nn.functional as F
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils.tools import dotdict
from driver.driver import ABC_Driver
from torch_geometric_temporal import METRLADatasetLoader
from other_model.other_model import make_default_model
import atd2022
torch.cuda.is_available()
torch.cuda.set_device(1)

# %%
cifar100_args = dotdict()

cifar100_args.name = 'cifar100'
cifar100_args.train_batch_size = 128
cifar100_args.predict_batch_size = 128
cifar100_args.device = ['cuda:1', 'cuda:6']
cifar100_args.train_epochs = 250
cifar100_args.lr = 0.01
cifar100_args.criterion = 'CE'
cifar100_args.optimizer = 'AdamW'
cifar100_args.scheduler = 'multistep'
cifar100_args.attack = {'fgsm':(0.005,), 'pgd':(0.005,0.1,20)}

activation = 'relu'
input_channel = 3
knpp = [48,96,144,240,336,432,528]

cifar100_args.layers=[
    ('cnn2d', ((input_channel, knpp[0], (3,3), 1, 1, 1, 1), 1, None, None, activation, False)),
    ('atrc2d', ((knpp[0], knpp[1], (3,3), 1, 1, 1, knpp[0]), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[1], knpp[2], (3,3), 1, 1, 1, knpp[0]), 1, 'first', (2,2), activation, True)),
    ('atrc2d', ((knpp[2], knpp[3], (3,3), 1, 1, 1, knpp[0]), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[3], knpp[4], (3,3), 1, 1, 1, knpp[0]), 1, 'first', (2,2), activation, True)),
    ('atrc2d', ((knpp[4], knpp[5], (3,3), 1, 1, 1, knpp[0]), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[5], knpp[6], (3,3), 1, 1, 1, knpp[0]), 1, 'first', (2,2), activation, True)),
#     ('cnn2d', ((knpp[-1], knpp[-1], (3,3), 1, 0, 1, knpp[0]), 1, None, None, activation, False)),
#     ('cnn2d', ((knpp[-1], knpp[-1], (2,2), 1, 0, 1, knpp[0]), 1, None, None, False, False)),
    ('adptavgpool', (1,1)),
    ('linear', (knpp[-1], 100, (1,2,3)))
]

# %%
cifar10_args = dotdict()

cifar10_args.name = 'cifar10'
cifar10_args.train_batch_size = 128
cifar10_args.predict_batch_size = 128
cifar10_args.device = ['cuda:1', 'cuda:6']

cifar10_args.train_epochs = 250
cifar10_args.lr = 0.01
cifar10_args.criterion = 'CE'
cifar10_args.optimizer = 'AdamW'
cifar10_args.scheduler = 'OneCycle'
cifar10_args.attack = {'fgsm':(0.005,), 'pgd':(0.005,0.1,20)}

activation = 'relu'
input_channel = 3
# knpp = [32,64,96,128,160,192,224]

# cifar10_args.layers=[
#     ('cnn2d', ((input_channel, knpp[0], (3,3), 1, 1, 1, 1), 1, None, None, activation, False)),
#     ('atc2d', ((knpp[0], knpp[1], (3,3), 1, 1, 1, knpp[0]), 1, None, None, activation, True)),
#     ('atc2d', ((knpp[1], knpp[2], (3,3), 1, 1, 1, knpp[0]), 1, 'first', (2,2), activation, True)),
#     ('atc2d', ((knpp[2], knpp[3], (3,3), 1, 1, 1, knpp[0]), 1, None, None, activation, True)),
#     ('atc2d', ((knpp[3], knpp[4], (3,3), 1, 1, 1, knpp[0]), 1, 'first', (2,2), activation, True)),
#     ('atc2d', ((knpp[4], knpp[5], (3,3), 1, 1, 1, knpp[0]), 1, None, None, activation, True)),
#     ('atc2d', ((knpp[5], knpp[6], (3,3), 1, 1, 1, knpp[0]), 1, 'first', (2,2), activation, True)),
#     ('cnn2d', ((knpp[-1], knpp[-1], (3,3), 1, 0, 1, knpp[0]), 1, None, None, activation, False)),
#     ('cnn2d', ((knpp[-1], knpp[-1], (2,2), 1, 0, 1, knpp[0]), 1, None, None, False, False)),
# #     ('adptavgpool', (1,1)),
#     ('linear', (knpp[-1], 10, (1,2,3)))\
# ]


# knpp = [64,96,128,192,256,384,512]
# groups=32
knpp = [48,96,144,240,336,432,528]
groups=48

cifar10_args.layers=[
    ('cnn2d', ((input_channel, knpp[0], (3,3), 1, 1, 1, 1), 1, None, None, activation, False)),
    ('atrc2d', ((knpp[0], knpp[1], (3,3), 1, 1, 1, groups), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[1], knpp[2], (3,3), 1, 1, 1, groups), 1, 'first', (2,2), activation, True)),
    ('atrc2d', ((knpp[2], knpp[3], (3,3), 1, 1, 1, groups), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[3], knpp[4], (3,3), 1, 1, 1, groups), 1, 'first', (2,2), activation, True)),
    ('atrc2d', ((knpp[4], knpp[5], (3,3), 1, 1, 1, groups), 1, None, None, activation, True)),
    ('atrc2d', ((knpp[5], knpp[6], (3,3), 1, 1, 1, groups), 1, 'first', (2,2), activation, True)),
    ('linear', (knpp[6], knpp[6], 1, 1)),
#     ('atrc2d', ((knpp[6], knpp[7], (3,3), 1, 1, 1, groups), 1, None, None, activation, True)),
    ('adptavgpool', (1,1)),
    ('linear', (knpp[-1], 10, (1,2,3)))
]

# %%
driver = ABC_Driver(cifar10_args, None, record_path=None, if_hash=False)
driver.train()
# Out:
# Use: ['cuda:1', 'cuda:6']
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# add record: 03/25/2023 13:12
# epoch: 0, train_loss: 1.885, test_metric: 0.461, time: 709.1594860553741
# epoch: 1, train_loss: 1.6523, test_metric: 0.5213, time: 708.2196772098541
# epoch: 2, train_loss: 1.519, test_metric: 0.5622, time: 707.9091649055481
# epoch: 3, train_loss: 1.4266, test_metric: 0.6089, time: 708.2026791572571
# epoch: 4, train_loss: 1.352, test_metric: 0.6095, time: 707.9433259963989
# epoch: 5, train_loss: 1.2946, test_metric: 0.6439, time: 707.7110548019409
# epoch: 6, train_loss: 1.233, test_metric: 0.6535, time: 708.4415442943573
# epoch: 7, train_loss: 1.1814, test_metric: 0.6911, time: 708.3085284233093
# epoch: 8, train_loss: 1.145, test_metric: 0.6799, time: 708.2502505779266
# epoch: 9, train_loss: 1.1106, test_metric: 0.7067, time: 708.2833693027496
# epoch: 10, train_loss: 1.0788, test_metric: 0.7344, time: 708.3292157649994
# epoch: 11, train_loss: 1.0448, test_metric: 0.6988, time: 708.154993057251
# epoch: 12, train_loss: 1.0038, test_metric: 0.7042, time: 708.2890994548798
# epoch: 13, train_loss: 0.9781, test_metric: 0.762, time: 707.9860217571259
# epoch: 14, train_loss: 0.9505, test_metric: 0.7662, time: 708.2423882484436
# epoch: 15, train_loss: 0.9245, test_metric: 0.7814, time: 707.953622341156
# epoch: 16, train_loss: 0.9022, test_metric: 0.7813, time: 707.640533208847
# epoch: 17, train_loss: 0.8799, test_metric: 0.7723, time: 709.2266411781311
# epoch: 18, train_loss: 0.8453, test_metric: 0.7982, time: 709.5429294109344
# epoch: 19, train_loss: 0.8178, test_metric: 0.8058, time: 709.6006135940552
# epoch: 20, train_loss: 0.7934, test_metric: 0.7964, time: 709.5191299915314
# epoch: 21, train_loss: 0.7749, test_metric: 0.8064, time: 708.7919592857361
# epoch: 22, train_loss: 0.7755, test_metric: 0.8147, time: 709.0925478935242
# epoch: 23, train_loss: 0.7579, test_metric: 0.828, time: 709.699615240097
# epoch: 24, train_loss: 0.7461, test_metric: 0.8036, time: 709.9205117225647
# epoch: 25, train_loss: 0.749, test_metric: 0.812, time: 709.7465057373047
# epoch: 26, train_loss: 0.7277, test_metric: 0.8266, time: 709.2809896469116
# epoch: 27, train_loss: 0.7357, test_metric: 0.7938, time: 709.2340416908264
# epoch: 28, train_loss: 0.7418, test_metric: 0.8103, time: 709.6245522499084
# epoch: 29, train_loss: 0.756, test_metric: 0.8022, time: 709.611566066742
# epoch: 30, train_loss: 0.7716, test_metric: 0.81, time: 709.6627712249756
# epoch: 31, train_loss: 0.7904, test_metric: 0.7932, time: 709.6563601493835
# epoch: 32, train_loss: 0.8238, test_metric: 0.7764, time: 709.5944819450378
# epoch: 33, train_loss: 0.8329, test_metric: 0.7973, time: 709.3778734207153
# epoch: 34, train_loss: 0.8597, test_metric: 0.7545, time: 709.1658866405487
# epoch: 35, train_loss: 0.875, test_metric: 0.7827, time: 711.2113749980927
# epoch: 36, train_loss: 0.9085, test_metric: 0.7643, time: 711.205023765564
# epoch: 37, train_loss: 0.9376, test_metric: 0.7764, time: 711.3684935569763
# epoch: 38, train_loss: 0.9515, test_metric: 0.7597, time: 711.2076237201691
# epoch: 39, train_loss: 0.978, test_metric: 0.7659, time: 711.3606860637665
# epoch: 40, train_loss: 0.9938, test_metric: 0.763, time: 711.1079008579254
# epoch: 41, train_loss: 1.0197, test_metric: 0.7578, time: 711.1648507118225
# epoch: 42, train_loss: 1.0534, test_metric: 0.7537, time: 710.4134583473206
# epoch: 43, train_loss: 1.0695, test_metric: 0.7368, time: 711.3728494644165
# epoch: 44, train_loss: 1.0959, test_metric: 0.696, time: 710.856103181839
# epoch: 45, train_loss: 1.1718, test_metric: 0.6839, time: 710.6628947257996
# epoch: 46, train_loss: 1.1715, test_metric: 0.7235, time: 711.19433760643
# epoch: 47, train_loss: 1.1744, test_metric: 0.7025, time: 711.5903611183167
# epoch: 48, train_loss: 1.2113, test_metric: 0.7308, time: 711.092413187027
# epoch: 49, train_loss: 1.2055, test_metric: 0.7126, time: 710.8136413097382
# epoch: 50, train_loss: 1.2316, test_metric: 0.6831, time: 685.6303839683533
# epoch: 51, train_loss: 1.2742, test_metric: 0.6592, time: 701.9026594161987

# %%
# torch.save(driver.model.state_dict(), "save/CIFAR100_ABCCNN_2023_03_13.pt")
