# %% [markdown]
# 2 CNN: 0.98
# 1 CNN: 0.9615 epoch 3
# 1 CNN: 0.9782 epoch 50
# ABC: 0.9575 batch 100, lr 0.0001, metrics criterion 'CE', epoch 3
# ABC: 0.9671 batch 100, lr 0.0001, metrics criterion 'CE', epoch 6
# ABC: 0.9768 epoch 50 kernel_per_pixel 8

# %%
import torch
import torchvision
import torch.nn.functional as F
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils.tools import dotdict
from driver.driver import ABC_Driver
from torch_geometric_temporal import METRLADatasetLoader
from other_model.other_model import make_default_model
import atd2022
torch.cuda.is_available()
torch.cuda.set_device(0)

# %%
atd_args = dotdict()

atd_args.name = 'atd'
atd_args.train_batch_size = 25
atd_args.predict_len = 4
atd_args.history_len = 7

atd_args.train_epochs= 10
atd_args.lr = 0.00009
atd_args.criterion = 'L1'
atd_args.scheduler = None

activation = 'relu'
pool_name = 'avg'
input_channel = 1
pixel_number = atd_args.history_len*5200
kernel_size = 6
knpp = 12
knpp2 = atd_args.predict_len

atd_args.layers=[
    ('agnostic', ((input_channel, knpp, kernel_size), 1, pool_name, (1,1), activation)),
    ('agnostic', ((knpp, knpp2, kernel_size), 1, pool_name, (1,1), activation)),
    ('linear', (knpp2*atd_args.history_len, atd_args.predict_len, (1,2), 1, (1, atd_args.predict_len))),
]

# %%
wt_args = dotdict()

wt_args.name = 'wiki_traffic'
wt_args.train_batch_size = 30
wt_args.predict_len = 1
wt_args.history_len = 5

wt_args.train_epochs= 10
wt_args.lr = 0.001
wt_args.criterion = 'L1'
wt_args.scheduler = None

activation = 'relu'
pool_name = 'avg'
input_channel = 1
pixel_number = wt_args.history_len*1400
kernel_size = 3
knpp = 5
knpp2 = 15

wt_args.layers=[
    ('specific', ((input_channel, knpp, kernel_size), 1, pool_name, (1,1), activation)),
    ('specific', ((knpp, knpp2, kernel_size), 1, pool_name, (1,1), activation)),
    ('linear', (knpp2*wt_args.history_len, wt_args.predict_len, (1,2), 1, (1, wt_args.predict_len))),
]

# %%
lat_args = dotdict()

lat_args.name = 'lat'
lat_args.train_batch_size = 30
lat_args.predict_len = 1
lat_args.history_len = 5

lat_args.train_epochs= 10
lat_args.lr = 0.001
lat_args.criterion = 'L1'
lat_args.scheduler = None

activation = 'relu'
pool_name = 'avg'
input_channel = 1
pixel_number = lat_args.history_len*207
kernel_size = 3
knpp = 5
knpp2 = 15

lat_args.layers=[
    ('specific', ((input_channel, knpp, kernel_size), 1, pool_name, (1,1), activation)),
    ('specific', ((knpp, knpp2, kernel_size), 1, pool_name, (1,1), activation)),
    ('linear', (knpp2*lat_args.history_len, lat_args.predict_len, (1,2), 1, (1, lat_args.predict_len))),
]

# %%
mnist_args = dotdict()

mnist_args.name = 'mnist'
mnist_args.train_batch_size = 60
mnist_args.predict_batch_size = 100

mnist_args.train_epochs = 10
mnist_args.lr = 0.0001
mnist_args.criterion = 'CE'
mnist_args.scheduler = None

activation = 'relu'
pool_name = 'avg'
input_channel = 1
pixel_number = 28*28
kernel_size = 25
knpp = 10
knpp2 = 20
knpp3 = 39

# mnist_args.layers=[
#     ('specific', ((input_channel, knpp, kernel_size), 1, pool_name, (1,1), activation)),
#     ('specific', ((knpp, knpp2, kernel_size), 1, pool_name, (1,1), activation)),
#     ('specific', ((knpp2, knpp3, kernel_size), 1, pool_name, (1,1), activation)),
#     ('attention', (knpp3, 3)),
#     ('linear', (knpp3, 10, (1,2,3))),
#     ('softmax', (1))
# ]

mnist_args.layers=[
    ('cnn2d', ((input_channel, knpp, (5,5), 1, 2), 1, pool_name, (1,1), activation)),
    ('cnn2d', ((knpp, knpp2, (5,5), 1, 2), 1, pool_name, (1,1), activation)),
    ('cnn2d', ((knpp2, knpp3, (5,5), 1, 2), 1, pool_name, (1,1), activation)),
    ('attention', (knpp3, 3)),
    ('linear', (knpp3, 10, (1,2,3))),
    ('softmax', (1))
]

# %%
cifar10_args = dotdict()

cifar10_args.name = 'cifar10'
cifar10_args.train_batch_size = 128
cifar10_args.predict_batch_size = 100

cifar10_args.train_epochs = 180
cifar10_args.lr = 0.1
cifar10_args.criterion = 'CE'
cifar10_args.scheduler = 'multistep'

activation = 'relu'
input_channel = 3
pixel_number = 32*32
kernel_size = 9
# knpp = [63, 63, 129, 129, 255, 255, 513, 513]
knpp = [16, 16, 16, 32, 32, 32, 64, 64, 64]

# cifar10_args.layers=[
#     ('specific', ((input_channel, knpp[0], kernel_size), 2, (1,1), activation)),
#     ('agnostic', ((knpp[0], knpp[1], kernel_size), 2, (2,2), activation)),
#     ('agnostic', ((knpp[1], knpp[2], kernel_size), 2, (1,1), activation)),
#     ('agnostic', ((knpp[2], knpp[3], kernel_size), 2, (2,2), activation)),
#     ('agnostic', ((knpp[3], knpp[4], kernel_size), 2, (1,1), activation)),
#     ('agnostic', ((knpp[4], knpp[5], kernel_size), 2, (2,2), activation)),
#     ('agnostic', ((knpp[5], knpp[6], kernel_size), 2, (1,1), activation)),
#     ('agnostic', ((knpp[6], knpp[7], kernel_size), 2, (2,2), activation)),
# #     ('agnostic', ((knpp[7], knpp[8], kernel_size), 2, (1,1), activation)),
# #     ('agnostic', ((knpp[8], knpp[9], kernel_size), 2, (2,2), activation)),
# #     ('attention', (knpp, 5, 4)),
#     ('linear', (int(knpp[-1]*pixel_number/(4**4)), 10, (1,2,3))),
#     ('softmax', (1))
# ]

# cifar10_args.layers=[
#     ('large', ((input_channel, 33, (3,3), 7, (1,1)), 2, (1,1), activation)),
#     ('large', ((33, 63, (3,3), 7, (1,1)), 2, (1,1), activation)),
#     ('large', ((63, 129, (3,3), 7, (1,1)), 2, (1,1), activation)),
#     ('large', ((129, 255, (3,3), 7, (1,1)), 2, (1,1), activation)),
#     ('linear', (int(33*pixel_number), 10, (1,2,3))),
#     ('softmax', 1)
# ]

cifar10_args.layers=[
    ('cnn2d', ((input_channel, knpp[0], (3,3), 1, 1), 1, (1,1), activation, False)),
    ('cnn2d', ((knpp[0], knpp[0], (3,3), 1, 1), 2, (1,1), activation)),
    ('cnn2d', ((knpp[0], knpp[1], (3,3), 1, 1), 2, (1,1), activation)),
    ('cnn2d', ((knpp[1], knpp[2], (3,3), 1, 1), 2, (1,1), activation)),
    ('cnn2d', ((knpp[2], knpp[3], (3,3), 1, 1), 2, (2,2), activation)),
    ('cnn2d', ((knpp[3], knpp[4], (3,3), 1, 1), 2, (1,1), activation)),
    ('cnn2d', ((knpp[4], knpp[5], (3,3), 1, 1), 2, (1,1), activation)),
    ('cnn2d', ((knpp[5], knpp[6], (3,3), 1, 1), 2, (2,2), activation)),
    ('cnn2d', ((knpp[6], knpp[7], (3,3), 1, 1), 2, (1,1), activation)),
    ('cnn2d', ((knpp[7], knpp[8], (3,3), 1, 1), 2, (1,1), activation)),
    ('adptavgpool', (1,1)),
    ('linear', (knpp[-1], 10, (1,2,3))),
    ('softmax', (1))
]

# %%
args = cifar10_args
data = None
# data = atd2022.io.read_csv()
# data = pd.read_csv('/scratch/mfeng/data/ABC/Wiki_Traffic/filled_selected_train_1.csv', index_col=0, header=[0,1,2,3], parse_dates=True)
# data = pd.read_csv('/scratch/mfeng/data/ABC/LA_Traffic/LA_Traffic.csv', index_col=0)
# data = data.head(200)

driver = ABC_Driver(args, data, record_path=None, if_hash=False)
driver.train()
# Out:
# Use GPU
# Files already downloaded and verified
# Files already downloaded and verified
# add record: 01/31/2023 23:58
# epoch: 0, train_loss: 2.1464, test_metric: 0.3124
# epoch: 1, train_loss: 2.023, test_metric: 0.4408
# epoch: 2, train_loss: 1.9395, test_metric: 0.5161
# epoch: 3, train_loss: 1.8871, test_metric: 0.5241
# epoch: 4, train_loss: 1.8541, test_metric: 0.5787
# epoch: 5, train_loss: 1.8226, test_metric: 0.6491
# epoch: 6, train_loss: 1.7977, test_metric: 0.6674
# epoch: 7, train_loss: 1.7774, test_metric: 0.6742
# epoch: 8, train_loss: 1.7552, test_metric: 0.6607
# epoch: 9, train_loss: 1.7419, test_metric: 0.7056
# epoch: 10, train_loss: 1.728, test_metric: 0.7049
# epoch: 11, train_loss: 1.718, test_metric: 0.721
# epoch: 12, train_loss: 1.7145, test_metric: 0.685
# epoch: 13, train_loss: 1.7062, test_metric: 0.6599
# epoch: 14, train_loss: 1.6979, test_metric: 0.7064
# epoch: 15, train_loss: 1.6928, test_metric: 0.7353
# epoch: 16, train_loss: 1.6882, test_metric: 0.7617
# epoch: 17, train_loss: 1.6832, test_metric: 0.7578
# epoch: 18, train_loss: 1.6795, test_metric: 0.7586
# epoch: 19, train_loss: 1.6738, test_metric: 0.7341
# epoch: 20, train_loss: 1.6765, test_metric: 0.7345
# epoch: 21, train_loss: 1.6679, test_metric: 0.749
# epoch: 22, train_loss: 1.6675, test_metric: 0.7629
# epoch: 23, train_loss: 1.665, test_metric: 0.7744
# epoch: 24, train_loss: 1.6621, test_metric: 0.7652
# epoch: 25, train_loss: 1.6596, test_metric: 0.7302
# epoch: 26, train_loss: 1.6578, test_metric: 0.7762
# epoch: 27, train_loss: 1.6545, test_metric: 0.7883
# epoch: 28, train_loss: 1.6517, test_metric: 0.7882
# epoch: 29, train_loss: 1.6506, test_metric: 0.7952
# epoch: 30, train_loss: 1.6488, test_metric: 0.788
# epoch: 31, train_loss: 1.6435, test_metric: 0.7695
# epoch: 32, train_loss: 1.6422, test_metric: 0.7852
# epoch: 33, train_loss: 1.6415, test_metric: 0.7968
# epoch: 34, train_loss: 1.6433, test_metric: 0.7975
# epoch: 35, train_loss: 1.6388, test_metric: 0.7754
# epoch: 36, train_loss: 1.6399, test_metric: 0.7893
# epoch: 37, train_loss: 1.6378, test_metric: 0.7655
# epoch: 38, train_loss: 1.6351, test_metric: 0.7969
# epoch: 39, train_loss: 1.6365, test_metric: 0.8013
# epoch: 40, train_loss: 1.6349, test_metric: 0.7918
# epoch: 41, train_loss: 1.6348, test_metric: 0.7886
# epoch: 42, train_loss: 1.6326, test_metric: 0.8146
# epoch: 43, train_loss: 1.6306, test_metric: 0.8244
# epoch: 44, train_loss: 1.6287, test_metric: 0.8129
# epoch: 45, train_loss: 1.6297, test_metric: 0.8243
# epoch: 46, train_loss: 1.6299, test_metric: 0.7758
# epoch: 47, train_loss: 1.6289, test_metric: 0.8115
# epoch: 48, train_loss: 1.6275, test_metric: 0.8075
# epoch: 49, train_loss: 1.626, test_metric: 0.8086
# epoch: 50, train_loss: 1.6243, test_metric: 0.8211
# epoch: 51, train_loss: 1.6248, test_metric: 0.8244
# epoch: 52, train_loss: 1.6212, test_metric: 0.8146
# epoch: 53, train_loss: 1.6219, test_metric: 0.7793
# epoch: 54, train_loss: 1.6229, test_metric: 0.8092
# epoch: 55, train_loss: 1.6186, test_metric: 0.8039
# epoch: 56, train_loss: 1.6226, test_metric: 0.808
# epoch: 57, train_loss: 1.6185, test_metric: 0.8187
# epoch: 58, train_loss: 1.6183, test_metric: 0.8204
# epoch: 59, train_loss: 1.6214, test_metric: 0.814
# epoch: 60, train_loss: 1.6183, test_metric: 0.8026
# epoch: 61, train_loss: 1.6164, test_metric: 0.8032
# epoch: 62, train_loss: 1.6166, test_metric: 0.756
# epoch: 63, train_loss: 1.6176, test_metric: 0.7589
# epoch: 64, train_loss: 1.6171, test_metric: 0.789
# epoch: 65, train_loss: 1.6162, test_metric: 0.8179
# epoch: 66, train_loss: 1.6164, test_metric: 0.7787
# epoch: 67, train_loss: 1.6142, test_metric: 0.819
# epoch: 68, train_loss: 1.6127, test_metric: 0.8234
# epoch: 69, train_loss: 1.6123, test_metric: 0.811
# epoch: 70, train_loss: 1.6104, test_metric: 0.8171
# epoch: 71, train_loss: 1.61, test_metric: 0.8125
# epoch: 72, train_loss: 1.613, test_metric: 0.8239
# epoch: 73, train_loss: 1.6092, test_metric: 0.8008
# epoch: 74, train_loss: 1.6109, test_metric: 0.8287
# epoch: 75, train_loss: 1.608, test_metric: 0.8204
# epoch: 76, train_loss: 1.6106, test_metric: 0.8272
# epoch: 77, train_loss: 1.6099, test_metric: 0.8262
# epoch: 78, train_loss: 1.6097, test_metric: 0.8004
# epoch: 79, train_loss: 1.6088, test_metric: 0.8408
# epoch: 80, train_loss: 1.6047, test_metric: 0.8147
# epoch: 81, train_loss: 1.605, test_metric: 0.8291
# epoch: 82, train_loss: 1.6064, test_metric: 0.8464
# epoch: 83, train_loss: 1.6049, test_metric: 0.8347
# epoch: 84, train_loss: 1.6043, test_metric: 0.8494
# epoch: 85, train_loss: 1.6038, test_metric: 0.8253
# epoch: 86, train_loss: 1.6037, test_metric: 0.8106
# epoch: 87, train_loss: 1.6045, test_metric: 0.8298
# epoch: 88, train_loss: 1.6039, test_metric: 0.8155
# epoch: 89, train_loss: 1.6008, test_metric: 0.8225
# epoch: 90, train_loss: 1.6043, test_metric: 0.8349
# epoch: 91, train_loss: 1.6043, test_metric: 0.796
# epoch: 92, train_loss: 1.6036, test_metric: 0.8152
# epoch: 93, train_loss: 1.5999, test_metric: 0.8063
# epoch: 94, train_loss: 1.6024, test_metric: 0.8195
# epoch: 95, train_loss: 1.5982, test_metric: 0.8075
# epoch: 96, train_loss: 1.6009, test_metric: 0.8315
# epoch: 97, train_loss: 1.6015, test_metric: 0.848
# epoch: 98, train_loss: 1.5996, test_metric: 0.8331
# epoch: 99, train_loss: 1.598, test_metric: 0.8291
# epoch: 100, train_loss: 1.6006, test_metric: 0.8249
# epoch: 101, train_loss: 1.6009, test_metric: 0.8292
# epoch: 102, train_loss: 1.5977, test_metric: 0.7991
# epoch: 103, train_loss: 1.6001, test_metric: 0.8116
# epoch: 104, train_loss: 1.5997, test_metric: 0.8345
# epoch: 105, train_loss: 1.5971, test_metric: 0.8312
# epoch: 106, train_loss: 1.5953, test_metric: 0.8332
# epoch: 107, train_loss: 1.5999, test_metric: 0.8505
# epoch: 108, train_loss: 1.6001, test_metric: 0.8328
# epoch: 109, train_loss: 1.5974, test_metric: 0.822
# epoch: 110, train_loss: 1.596, test_metric: 0.8219
# epoch: 111, train_loss: 1.5985, test_metric: 0.8232
# epoch: 112, train_loss: 1.5989, test_metric: 0.8182
# epoch: 113, train_loss: 1.5959, test_metric: 0.8198
# epoch: 114, train_loss: 1.5974, test_metric: 0.8174
# epoch: 115, train_loss: 1.5984, test_metric: 0.8222
# epoch: 116, train_loss: 1.5977, test_metric: 0.842
# epoch: 117, train_loss: 1.5938, test_metric: 0.8382
# epoch: 118, train_loss: 1.5949, test_metric: 0.7816
# epoch: 119, train_loss: 1.5967, test_metric: 0.8386
# epoch: 120, train_loss: 1.5981, test_metric: 0.8312
# epoch: 121, train_loss: 1.5954, test_metric: 0.8218
# epoch: 122, train_loss: 1.5963, test_metric: 0.8279
# epoch: 123, train_loss: 1.5921, test_metric: 0.8452
# epoch: 124, train_loss: 1.5966, test_metric: 0.8264
# epoch: 125, train_loss: 1.5929, test_metric: 0.8296
# epoch: 126, train_loss: 1.5947, test_metric: 0.8373
# epoch: 127, train_loss: 1.5918, test_metric: 0.8448
# epoch: 128, train_loss: 1.5948, test_metric: 0.8425
# epoch: 129, train_loss: 1.5943, test_metric: 0.8475
# epoch: 130, train_loss: 1.5916, test_metric: 0.8417
# epoch: 131, train_loss: 1.5916, test_metric: 0.8142
# epoch: 132, train_loss: 1.5925, test_metric: 0.8113
# epoch: 133, train_loss: 1.5927, test_metric: 0.8391
# epoch: 134, train_loss: 1.5927, test_metric: 0.8514
# epoch: 135, train_loss: 1.5897, test_metric: 0.8145
# epoch: 136, train_loss: 1.5894, test_metric: 0.8348
# epoch: 137, train_loss: 1.5916, test_metric: 0.8225
# epoch: 138, train_loss: 1.5898, test_metric: 0.8423
# epoch: 139, train_loss: 1.5896, test_metric: 0.8203
# epoch: 140, train_loss: 1.5919, test_metric: 0.8286

# %%
driver.metric()
